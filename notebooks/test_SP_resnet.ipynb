# %%
from texture.networks import SP_ResNet

from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
# Out:
# Using TensorFlow backend.

# %%
net = SP_ResNet(6, (100,800,3))

net.summary()

SVG(model_to_dot(net).create(prog='dot', format='svg'))
# Out:
# [None, 16]
# [None, 64]
# [None, 256]
# [None, 1024]
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 100, 800, 3)  0
# __________________________________________________________________________________________________
# entry_conv (Conv2D)             (None, 50, 400, 64)  9472        input[0][0]
# __________________________________________________________________________________________________
# entry_bn (BatchNormalization)   (None, 50, 400, 64)  256         entry_conv[0][0]
# __________________________________________________________________________________________________
# entry_relu (Activation)         (None, 50, 400, 64)  0           entry_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 25, 200, 64)  0           entry_relu[0][0]
# __________________________________________________________________________________________________
# sp_res_block0_0_conv1 (Conv2D)  (None, 13, 100, 64)  36928       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# sp_res_block0_0_bn1 (BatchNorma (None, 13, 100, 64)  256         sp_res_block0_0_conv1[0][0]
# __________________________________________________________________________________________________
# sp_res_block0_0_relu1 (Activati (None, 13, 100, 64)  0           sp_res_block0_0_bn1[0][0]
# __________________________________________________________________________________________________
# sp_res_block0_0_conv2 (Conv2D)  (None, 13, 100, 64)  36928       sp_res_block0_0_relu1[0][0]
# __________________________________________________________________________________________________
# sp_res_block0_0_bn2 (BatchNorma (None, 13, 100, 64)  256         sp_res_block0_0_conv2[0][0]
# __________________________________________________________________________________________________
# sp_res_block0_0_relu2 (Activati (None, 13, 100, 64)  0           sp_res_block0_0_bn2[0][0]
# __________________________________________________________________________________________________
# sp_res_block0_0_globalpool (Glo (None, 64)           0           sp_res_block0_0_relu2[0][0]
# __________________________________________________________________________________________________
# sp_res_block0_0_compress (Dense (None, 4)            256         sp_res_block0_0_globalpool[0][0]
# __________________________________________________________________________________________________
# sp_res_block0_0_expand (Dense)  (None, 64)           256         sp_res_block0_0_compress[0][0]
# __________________________________________________________________________________________________
# sp_res_block0_0_excite (Multipl (None, 13, 100, 64)  0           sp_res_block0_0_relu2[0][0]
#                                                                  sp_res_block0_0_expand[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 13, 100, 64)  4096        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# sp_res_block0_0_shortcut (Add)  (None, 13, 100, 64)  0           sp_res_block0_0_excite[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# sp_res_block0_1_conv1 (Conv2D)  (None, 13, 100, 64)  36928       sp_res_block0_0_shortcut[0][0]
# __________________________________________________________________________________________________
# sp_res_block0_1_bn1 (BatchNorma (None, 13, 100, 64)  256         sp_res_block0_1_conv1[0][0]
# __________________________________________________________________________________________________
# sp_res_block0_1_relu1 (Activati (None, 13, 100, 64)  0           sp_res_block0_1_bn1[0][0]
# __________________________________________________________________________________________________
# sp_res_block0_1_conv2 (Conv2D)  (None, 13, 100, 64)  36928       sp_res_block0_1_relu1[0][0]
# __________________________________________________________________________________________________
# sp_res_block0_1_bn2 (BatchNorma (None, 13, 100, 64)  256         sp_res_block0_1_conv2[0][0]
# __________________________________________________________________________________________________
# sp_res_block0_1_relu2 (Activati (None, 13, 100, 64)  0           sp_res_block0_1_bn2[0][0]
# __________________________________________________________________________________________________
# sp_res_block0_1_globalpool (Glo (None, 64)           0           sp_res_block0_1_relu2[0][0]
# __________________________________________________________________________________________________
# sp_res_block0_1_compress (Dense (None, 4)            256         sp_res_block0_1_globalpool[0][0]
# __________________________________________________________________________________________________
# sp_res_block0_1_expand (Dense)  (None, 64)           256         sp_res_block0_1_compress[0][0]
# __________________________________________________________________________________________________
# sp_res_block0_1_excite (Multipl (None, 13, 100, 64)  0           sp_res_block0_1_relu2[0][0]
#                                                                  sp_res_block0_1_expand[0][0]
# __________________________________________________________________________________________________
# sp_res_block0_1_shortcut (Add)  (None, 13, 100, 64)  0           sp_res_block0_1_excite[0][0]
#                                                                  sp_res_block0_0_shortcut[0][0]
# __________________________________________________________________________________________________
# sp_res_block1_0_conv1 (Conv2D)  (None, 7, 50, 128)   73856       sp_res_block0_1_shortcut[0][0]
# __________________________________________________________________________________________________
# sp_res_block1_0_bn1 (BatchNorma (None, 7, 50, 128)   512         sp_res_block1_0_conv1[0][0]
# __________________________________________________________________________________________________
# sp_res_block1_0_relu1 (Activati (None, 7, 50, 128)   0           sp_res_block1_0_bn1[0][0]
# __________________________________________________________________________________________________
# sp_res_block1_0_conv2 (Conv2D)  (None, 7, 50, 128)   147584      sp_res_block1_0_relu1[0][0]
# __________________________________________________________________________________________________
# sp_res_block1_0_bn2 (BatchNorma (None, 7, 50, 128)   512         sp_res_block1_0_conv2[0][0]
# __________________________________________________________________________________________________
# sp_res_block1_0_relu2 (Activati (None, 7, 50, 128)   0           sp_res_block1_0_bn2[0][0]
# __________________________________________________________________________________________________
# sp_res_block1_0_globalpool (Glo (None, 128)          0           sp_res_block1_0_relu2[0][0]
# __________________________________________________________________________________________________
# sp_res_block1_0_compress (Dense (None, 8)            1024        sp_res_block1_0_globalpool[0][0]
# __________________________________________________________________________________________________
# sp_res_block1_0_expand (Dense)  (None, 128)          1024        sp_res_block1_0_compress[0][0]
# __________________________________________________________________________________________________
# sp_res_block1_0_excite (Multipl (None, 7, 50, 128)   0           sp_res_block1_0_relu2[0][0]
#                                                                  sp_res_block1_0_expand[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 7, 50, 128)   8192        sp_res_block0_1_shortcut[0][0]
# __________________________________________________________________________________________________
# sp_res_block1_0_shortcut (Add)  (None, 7, 50, 128)   0           sp_res_block1_0_excite[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# sp_res_block1_1_conv1 (Conv2D)  (None, 7, 50, 128)   147584      sp_res_block1_0_shortcut[0][0]
# __________________________________________________________________________________________________
# sp_res_block1_1_bn1 (BatchNorma (None, 7, 50, 128)   512         sp_res_block1_1_conv1[0][0]
# __________________________________________________________________________________________________
# sp_res_block1_1_relu1 (Activati (None, 7, 50, 128)   0           sp_res_block1_1_bn1[0][0]
# __________________________________________________________________________________________________
# sp_res_block1_1_conv2 (Conv2D)  (None, 7, 50, 128)   147584      sp_res_block1_1_relu1[0][0]
# __________________________________________________________________________________________________
# sp_res_block1_1_bn2 (BatchNorma (None, 7, 50, 128)   512         sp_res_block1_1_conv2[0][0]
# __________________________________________________________________________________________________
# sp_res_block1_1_relu2 (Activati (None, 7, 50, 128)   0           sp_res_block1_1_bn2[0][0]
# __________________________________________________________________________________________________
# sp_res_block1_1_globalpool (Glo (None, 128)          0           sp_res_block1_1_relu2[0][0]
# __________________________________________________________________________________________________
# sp_res_block1_1_compress (Dense (None, 8)            1024        sp_res_block1_1_globalpool[0][0]
# __________________________________________________________________________________________________
# sp_res_block1_1_expand (Dense)  (None, 128)          1024        sp_res_block1_1_compress[0][0]
# __________________________________________________________________________________________________
# sp_res_block1_1_excite (Multipl (None, 7, 50, 128)   0           sp_res_block1_1_relu2[0][0]
#                                                                  sp_res_block1_1_expand[0][0]
# __________________________________________________________________________________________________
# sp_res_block1_1_shortcut (Add)  (None, 7, 50, 128)   0           sp_res_block1_1_excite[0][0]
#                                                                  sp_res_block1_0_shortcut[0][0]
# __________________________________________________________________________________________________
# sp_res_block2_0_conv1 (Conv2D)  (None, 4, 25, 256)   295168      sp_res_block1_1_shortcut[0][0]
# __________________________________________________________________________________________________
# sp_res_block2_0_bn1 (BatchNorma (None, 4, 25, 256)   1024        sp_res_block2_0_conv1[0][0]
# __________________________________________________________________________________________________
# sp_res_block2_0_relu1 (Activati (None, 4, 25, 256)   0           sp_res_block2_0_bn1[0][0]
# __________________________________________________________________________________________________
# sp_res_block2_0_conv2 (Conv2D)  (None, 4, 25, 256)   590080      sp_res_block2_0_relu1[0][0]
# __________________________________________________________________________________________________
# sp_res_block2_0_bn2 (BatchNorma (None, 4, 25, 256)   1024        sp_res_block2_0_conv2[0][0]
# __________________________________________________________________________________________________
# sp_res_block2_0_relu2 (Activati (None, 4, 25, 256)   0           sp_res_block2_0_bn2[0][0]
# __________________________________________________________________________________________________
# sp_res_block2_0_globalpool (Glo (None, 256)          0           sp_res_block2_0_relu2[0][0]
# __________________________________________________________________________________________________
# sp_res_block2_0_compress (Dense (None, 16)           4096        sp_res_block2_0_globalpool[0][0]
# __________________________________________________________________________________________________
# sp_res_block2_0_expand (Dense)  (None, 256)          4096        sp_res_block2_0_compress[0][0]
# __________________________________________________________________________________________________
# sp_res_block2_0_excite (Multipl (None, 4, 25, 256)   0           sp_res_block2_0_relu2[0][0]
#                                                                  sp_res_block2_0_expand[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 4, 25, 256)   32768       sp_res_block1_1_shortcut[0][0]
# __________________________________________________________________________________________________
# sp_res_block2_0_shortcut (Add)  (None, 4, 25, 256)   0           sp_res_block2_0_excite[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# sp_res_block2_1_conv1 (Conv2D)  (None, 4, 25, 256)   590080      sp_res_block2_0_shortcut[0][0]
# __________________________________________________________________________________________________
# sp_res_block2_1_bn1 (BatchNorma (None, 4, 25, 256)   1024        sp_res_block2_1_conv1[0][0]
# __________________________________________________________________________________________________
# sp_res_block2_1_relu1 (Activati (None, 4, 25, 256)   0           sp_res_block2_1_bn1[0][0]
# __________________________________________________________________________________________________
# sp_res_block2_1_conv2 (Conv2D)  (None, 4, 25, 256)   590080      sp_res_block2_1_relu1[0][0]
# __________________________________________________________________________________________________
# sp_res_block2_1_bn2 (BatchNorma (None, 4, 25, 256)   1024        sp_res_block2_1_conv2[0][0]
# __________________________________________________________________________________________________
# sp_res_block2_1_relu2 (Activati (None, 4, 25, 256)   0           sp_res_block2_1_bn2[0][0]
# __________________________________________________________________________________________________
# sp_res_block2_1_globalpool (Glo (None, 256)          0           sp_res_block2_1_relu2[0][0]
# __________________________________________________________________________________________________
# sp_res_block2_1_compress (Dense (None, 16)           4096        sp_res_block2_1_globalpool[0][0]
# __________________________________________________________________________________________________
# sp_res_block2_1_expand (Dense)  (None, 256)          4096        sp_res_block2_1_compress[0][0]
# __________________________________________________________________________________________________
# sp_res_block2_1_excite (Multipl (None, 4, 25, 256)   0           sp_res_block2_1_relu2[0][0]
#                                                                  sp_res_block2_1_expand[0][0]
# __________________________________________________________________________________________________
# sp_res_block2_1_shortcut (Add)  (None, 4, 25, 256)   0           sp_res_block2_1_excite[0][0]
#                                                                  sp_res_block2_0_shortcut[0][0]
# __________________________________________________________________________________________________
# sp_res_block3_0_conv1 (Conv2D)  (None, 2, 13, 512)   1180160     sp_res_block2_1_shortcut[0][0]
# __________________________________________________________________________________________________
# sp_res_block3_0_bn1 (BatchNorma (None, 2, 13, 512)   2048        sp_res_block3_0_conv1[0][0]
# __________________________________________________________________________________________________
# sp_res_block3_0_relu1 (Activati (None, 2, 13, 512)   0           sp_res_block3_0_bn1[0][0]
# __________________________________________________________________________________________________
# sp_res_block3_0_conv2 (Conv2D)  (None, 2, 13, 512)   2359808     sp_res_block3_0_relu1[0][0]
# __________________________________________________________________________________________________
# sp_res_block3_0_bn2 (BatchNorma (None, 2, 13, 512)   2048        sp_res_block3_0_conv2[0][0]
# __________________________________________________________________________________________________
# sp_res_block3_0_relu2 (Activati (None, 2, 13, 512)   0           sp_res_block3_0_bn2[0][0]
# __________________________________________________________________________________________________
# sp_res_block3_0_globalpool (Glo (None, 512)          0           sp_res_block3_0_relu2[0][0]
# __________________________________________________________________________________________________
# sp_res_block3_0_compress (Dense (None, 32)           16384       sp_res_block3_0_globalpool[0][0]
# __________________________________________________________________________________________________
# sp_res_block3_0_expand (Dense)  (None, 512)          16384       sp_res_block3_0_compress[0][0]
# __________________________________________________________________________________________________
# sp_res_block3_0_excite (Multipl (None, 2, 13, 512)   0           sp_res_block3_0_relu2[0][0]
#                                                                  sp_res_block3_0_expand[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 2, 13, 512)   131072      sp_res_block2_1_shortcut[0][0]
# __________________________________________________________________________________________________
# sp_res_block3_0_shortcut (Add)  (None, 2, 13, 512)   0           sp_res_block3_0_excite[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# sp_res_block3_1_conv1 (Conv2D)  (None, 2, 13, 512)   2359808     sp_res_block3_0_shortcut[0][0]
# __________________________________________________________________________________________________
# sp_res_block3_1_bn1 (BatchNorma (None, 2, 13, 512)   2048        sp_res_block3_1_conv1[0][0]
# __________________________________________________________________________________________________
# sp_res_block3_1_relu1 (Activati (None, 2, 13, 512)   0           sp_res_block3_1_bn1[0][0]
# __________________________________________________________________________________________________
# sp_res_block3_1_conv2 (Conv2D)  (None, 2, 13, 512)   2359808     sp_res_block3_1_relu1[0][0]
# __________________________________________________________________________________________________
# sp_res_block3_1_bn2 (BatchNorma (None, 2, 13, 512)   2048        sp_res_block3_1_conv2[0][0]
# __________________________________________________________________________________________________
# sp_res_block3_1_relu2 (Activati (None, 2, 13, 512)   0           sp_res_block3_1_bn2[0][0]
# __________________________________________________________________________________________________
# sp_res_block3_1_globalpool (Glo (None, 512)          0           sp_res_block3_1_relu2[0][0]
# __________________________________________________________________________________________________
# sp_res_block3_1_compress (Dense (None, 32)           16384       sp_res_block3_1_globalpool[0][0]
# __________________________________________________________________________________________________
# sp_res_block3_1_expand (Dense)  (None, 512)          16384       sp_res_block3_1_compress[0][0]
# __________________________________________________________________________________________________
# sp_res_block3_1_excite (Multipl (None, 2, 13, 512)   0           sp_res_block3_1_relu2[0][0]
#                                                                  sp_res_block3_1_expand[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 1, 1, 4)      0           sp_res_block0_1_compress[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 1, 1, 8)      0           sp_res_block1_1_compress[0][0]
# __________________________________________________________________________________________________
# reshape_13 (Reshape)            (None, 1, 1, 16)     0           sp_res_block2_1_compress[0][0]
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (None, 1, 1, 32)     0           sp_res_block3_1_compress[0][0]
# __________________________________________________________________________________________________
# sp_res_block3_1_shortcut (Add)  (None, 2, 13, 512)   0           sp_res_block3_1_excite[0][0]
#                                                                  sp_res_block3_0_shortcut[0][0]
# __________________________________________________________________________________________________
# bilinear_pooling0 (Lambda)      (None, 16)           0           reshape_9[0][0]
#                                                                  reshape_9[0][0]
# __________________________________________________________________________________________________
# bilinear_pooling1 (Lambda)      (None, 64)           0           reshape_11[0][0]
#                                                                  reshape_11[0][0]
# __________________________________________________________________________________________________
# bilinear_pooling2 (Lambda)      (None, 256)          0           reshape_13[0][0]
#                                                                  reshape_13[0][0]
# __________________________________________________________________________________________________
# bilinear_pooling3 (Lambda)      (None, 1024)         0           reshape_15[0][0]
#                                                                  reshape_15[0][0]
# __________________________________________________________________________________________________
# global_pooling_top (GlobalAvera (None, 512)          0           sp_res_block3_1_shortcut[0][0]
# __________________________________________________________________________________________________
# feature_concat (Concatenate)    (None, 1872)         0           bilinear_pooling0[0][0]
#                                                                  bilinear_pooling1[0][0]
#                                                                  bilinear_pooling2[0][0]
#                                                                  bilinear_pooling3[0][0]
#                                                                  global_pooling_top[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 6)            11238       feature_concat[0][0]
# ==================================================================================================
# Total params: 11,288,806
# Trainable params: 11,280,998
# Non-trainable params: 7,808
# __________________________________________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(net, to_file='SP_ResNet18_bilinear.png')
