# %%
import numpy as np
import random
import matplotlib.pyplot as plt

from texture import datasets

# %%
[_ for _ in dir(datasets) if _[0] != '_' and _[0].upper() == _[0]]
# Out:
# ['DTDDataset', 'Dataset', 'DatasetSequence', 'FMDDataset', 'Sequence']

# %% [markdown]
# # `DTD`: Describable Textures

# %%
dtd = datasets.DTDDataset('/home/administrator/Dropbox/benchmark/dtd/')
dtd
# Out:
# DTD Dataset
# Num classes: 47
# Split: 1
# Input shape: (224, 224, 3)

# %%
dtd.load_or_generate_data()
# Out:
# /home/administrator/anaconda3/envs/core-dev/lib/python3.6/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "

# %%
dtd.X_train.shape, dtd.y_train.shape, dtd.X_test.shape, dtd.y_test.shape
# Out:
# ((3760, 224, 224, 3), (3760, 47), (1880, 224, 224, 3), (1880, 47))

# %%
_ = datasets.util.show_sample(dtd)

# %% [markdown]
# # `FMD`: Flicker Materials

# %%
fmd = datasets.FMDDataset('/home/administrator/Dropbox/benchmark/FlickrMaterials/')
fmd
# Out:
# ['fabric', 'foliage', 'glass', 'leather', 'metal', 'paper', 'plastic', 'stone', 'water', 'wood']
# FMD Dataset
# Num classes: 10
# Random seed: None
# Input shape: (224, 224, 3)

# %%
fmd.load_or_generate_data()
# Out:
# /home/administrator/anaconda3/envs/core-dev/lib/python3.6/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "

# %%
fmd.X_train.shape, fmd.y_train.shape, fmd.X_test.shape, fmd.y_test.shape
# Out:
# ((900, 224, 224, 3), (900, 10), (100, 224, 224, 3), (100, 10))

# %%
_ = datasets.util.show_sample(fmd)
